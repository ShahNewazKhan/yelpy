# %%
# Import deps
import gzip
import pprint
import boto3
import ujson
import pandas as pd
import numpy as np
## Download and parse the incoming data
### The data are [here](s3://dataincubator-course/mldata/yelp_train_academic_dataset_business.json.gz)

# %%
# !mkdir data
s3_client = boto3.client('s3')
bucket = 'aida-practice-data'
prefix = '/Users/shah/projects/vision_critical/apache_spark/yelp/data'

# List all objects within a S3 bucket path
response = s3_client.list_objects(Bucket = bucket)

# Loop through each file
for file in response['Contents']:

    # Get the file name
    name = file['Key'].rsplit('/', 1)
    
    if '.gz' not in name[1]:
        print('skipping dir ' + str(name))
        continue
    
    # Download each file to local disk
    s3_client.download_file(bucket, file['Key'], prefix + '/' + name[1])
# Out:
# skipping dir ['yelp', '']
# skipping dir ['yelp/business', '']
# skipping dir ['yelp/checkin', '']
# skipping dir ['yelp/photos', '']
# skipping dir ['yelp/reviews', '']
# skipping dir ['yelp/tip', '']
# skipping dir ['yelp/user', '']

# %%
# !mkdir data/review && mv data/review.* data/review
# !mkdir data/business && mv data/business.* data/business
# !mkdir data/checkin && mv data/checkin.* data/checkin
# !mkdir data/photos && mv data/photos.* data/photos
# !mkdir data/tip && mv data/tip.* data/tip 
# !mkdir data/user && mv data/user.* data/user

# !ls -la data
# Out:
# total 0
# drwxr-xr-x   8 shah  staff   272 20 Dec 13:50 .
# drwxr-xr-x   9 shah  staff   306 20 Dec 13:50 ..
# drwxr-xr-x   6 shah  staff   204 20 Dec 13:50 business
# drwxr-xr-x   5 shah  staff   170 20 Dec 13:50 checkin
# drwxr-xr-x   6 shah  staff   204 20 Dec 13:50 photos
# drwxr-xr-x  97 shah  staff  3298 20 Dec 13:50 review
# drwxr-xr-x  23 shah  staff   782 20 Dec 13:50 tip
# drwxr-xr-x  26 shah  staff   884 20 Dec 13:50 user

# %%
# read in all the compressed business data
with gzip.open('data/business/business.json1.gz', 'rb') as f:
    file_content = f.readlines() # reads each line as bytes and places in list
with gzip.open('data/business/business.json2.gz', 'rb') as f:
    file_content += f.readlines() # reads each line as bytes and places in list
with gzip.open('data/business/business.json3.gz', 'rb') as f:
    file_content += f.readlines() # reads each line as bytes and places in list
with gzip.open('data/business/business.json4.gz', 'rb') as f:
    file_content += f.readlines() # reads each line as bytes and places in list

# stringify each file_content list element to a str and strip \n
def cleanse_file_content_list():
    for line in range(0, len(file_content)):
        line_str = file_content[line].decode('utf-8')
        file_content[line] = line_str.rstrip('\n')
        file_content[line] = ujson.loads(file_content[line])
        
cleanse_file_content_list()

# %%
df = pd.DataFrame(file_content)
df.info()
df['city'] = df['city'].str.lower()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156639 entries, 0 to 156638
# Data columns (total 15 columns):
# address         156639 non-null object
# attributes      156639 non-null object
# business_id     156639 non-null object
# categories      156639 non-null object
# city            156639 non-null object
# hours           156639 non-null object
# is_open         156639 non-null int64
# latitude        156638 non-null float64
# longitude       156638 non-null float64
# name            156639 non-null object
# neighborhood    156639 non-null object
# postal_code     156639 non-null object
# review_count    156639 non-null int64
# stars           156639 non-null float64
# state           156639 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 17.9+ MB

# %%
# extract 'city' & 'stars' column to new dataframe
city_df = df[['city', 'stars']]
city_df.info()
city_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156639 entries, 0 to 156638
# Data columns (total 2 columns):
# city     156639 non-null object
# stars    156639 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.4+ MB
#                     city  stars
# 0       richmond heights    2.0
# 1              charlotte    4.5
# 2                toronto    4.5
# 3             scottsdale    3.0
# 4                phoenix    4.5
# 5                phoenix    5.0
# 6                phoenix    5.0
# 7             pittsburgh    2.5
# 8               mcmurray    5.0
# 9                gilbert    5.0
# 10             las vegas    4.5
# 11            scottsdale    4.5
# 12                  mesa    2.0
# 13              avondale    4.5
# 14              matthews    2.0
# 15               stanley    3.0
# 16                  mesa    3.5
# 17             cleveland    3.0
# 18             cleveland    4.0
# 19             las vegas    3.5
# 20             pineville    3.0
# ...

# %%
# group by city & aggregate rating
grouped_city_df = city_df.groupby('city')
print(grouped_city_df['stars'].agg(np.mean))
#aggregated_city_gb = grouped_city_df['stars'].agg(np.mean)
# Out:
# city
#                                3.333333
# 110 las vegas                  5.000000
# aberdour                       4.000000
# aberlady                       4.250000
# agincourt                      2.500000
# ahwahtukee                     5.000000
# ahwatukee                      3.875000
# ahwatukee foothills village    5.000000
# aichwald                       3.500000
# ajax                           3.303398
# alburg                         5.000000
# allegheny                      5.000000
# allison park                   3.565217
# ambridge                       4.160714
# amherst                        3.515152
# anjou                          3.208333
# ansnorveldt                    4.500000
# anthem                         3.593407
# arlington                      4.500000
# arnold                         3.875000
# arrowhead                      3.000000
# ashburn                        4.500000
# aspinwall                      3.911765
# ...

# %%
dummy_cities_df = pd.get_dummies(aggr_city_df['city'])
aggr_city_df = pd.concat([aggr_city_df, dummy_cities_df], axis=1)
aggr_city_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-6aeb5106e31d> in <module>()
# ...

# %%
The aim of the task is to lay out the architecture and some initial code for a system that supports analytics on a live stream of Twitter feed. This is an open problem, and there is not one right answer, but write code, interfaces, class stubs keeping in mind two things:

    For the demo, we want to see working code that demonstrates one simple analytics: a classifier that returns a list of tweets from a stream of live tweets that contain the substring: "looking for a job in investment banking". Choose what you think is an appropriate endpoint from the Twitter API (https://dev.twitter.com/streaming/overview).
    Keep in mind that the system architecture should allow for flexibility in two ways: (1) the type of analytics that will be supported in the future (e.g., natural language processing as opposed a simple substring I'm asking you now) and (2) the ability to target tweets by certain criteria, e.g., geographical location. Express the architecture as interfaces, class stubs, member fields, and method stubs in the code.

You can use any programming language, tool, or third party libraries that you believe is the best for this task.

I want you to show off your code through a demo, and walk us through the code, emphasizing on the architecture you come up with and justifying any design decisions.
